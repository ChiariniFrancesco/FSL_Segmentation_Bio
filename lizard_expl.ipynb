# %%
import torch
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
img_np = r'C:\Users\franc\Desktop\progetti_vari\tesi_pd\conic-challenge-dataset\data\images.npy'
lab_np = r"C:\Users\franc\Desktop\progetti_vari\tesi_pd\conic-challenge-dataset\data\labels.npy"

# %%
img = np.load(img_np)
labels = np.load(lab_np)
print(img.shape)
print(labels.shape)
# Out:
# (4981, 256, 256, 3)
# (4981, 256, 256, 2)

# %%
img_1 = img[0][:][:][:]
print(img_1.shape)
mask_1 = labels[0][:,:,-1]
plt.figure()
plt.imshow(img_1)
plt.figure()
plt.imshow(mask_1, cmap='grey', alpha=0.4)
plt.figure()
plt.imshow(img_1)
plt.imshow(mask_1, cmap='turbo', alpha=0.4)
plt.show()
# Out:
# (256, 256, 3)
